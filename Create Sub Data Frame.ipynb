# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"

# %%
df = pd.read_csv(url, error_bad_lines=False)

# %%
df_new = df.loc[(df["location"] == 'India') | (df["location"] == 'Zimbabwe')]

# %%
df_new
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 64851       IND      Asia     India  2020-01-30          1.0        1.0
# 64852       IND      Asia     India  2020-01-31          1.0        0.0
# 64853       IND      Asia     India  2020-02-01          1.0        0.0
# 64854       IND      Asia     India  2020-02-02          2.0        1.0
# 64855       IND      Asia     India  2020-02-03          3.0        1.0
# ...         ...       ...       ...         ...          ...        ...
# 154556      ZWE    Africa  Zimbabwe  2022-01-10     223000.0     1082.0
# 154557      ZWE    Africa  Zimbabwe  2022-01-11     223000.0        0.0
# 154558      ZWE    Africa  Zimbabwe  2022-01-12     224433.0     1433.0
# 154559      ZWE    Africa  Zimbabwe  2022-01-13     225084.0      651.0
# 154560      ZWE    Africa  Zimbabwe  2022-01-14     225637.0      553.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 64851                  NaN           NaN         NaN                  NaN
# 64852                  NaN           NaN         NaN                  NaN
# 64853                  NaN           NaN         NaN                  NaN
# 64854                  NaN           NaN         NaN                  NaN
# 64855                  NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 154556             987.571        5180.0        32.0               19.000
# 154557             760.286        5180.0         0.0               14.571
# 154558             768.000        5215.0        35.0               17.571
# 154559             700.857        5222.0         7.0               16.286
# 154560             622.143        5238.0        16.0               14.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 64851   ...             1.9          20.6                  59.550
# 64852   ...             1.9          20.6                  59.550
# 64853   ...             1.9          20.6                  59.550
# 64854   ...             1.9          20.6                  59.550
# 64855   ...             1.9          20.6                  59.550
# ...     ...             ...           ...                     ...
# 154556  ...             1.6          30.7                  36.791
# 154557  ...             1.6          30.7                  36.791
# 154558  ...             1.6          30.7                  36.791
# 154559  ...             1.6          30.7                  36.791
# 154560  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 64851                         0.53            69.66                    0.645
# 64852                         0.53            69.66                    0.645
# 64853                         0.53            69.66                    0.645
# 64854                         0.53            69.66                    0.645
# 64855                         0.53            69.66                    0.645
# ...                            ...              ...                      ...
# 154556                        1.70            61.49                    0.571
# 154557                        1.70            61.49                    0.571
# 154558                        1.70            61.49                    0.571
# 154559                        1.70            61.49                    0.571
# 154560                        1.70            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 64851                                    NaN                          NaN
# 64852                                    NaN                          NaN
# 64853                                    NaN                          NaN
# 64854                                    NaN                          NaN
# 64855                                    NaN                          NaN
# ...                                      ...                          ...
# 154556                                   NaN                          NaN
# 154557                                   NaN                          NaN
# 154558                                   NaN                          NaN
# 154559                                   NaN                          NaN
# 154560                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 64851                NaN                                      NaN
# 64852                NaN                                      NaN
# 64853                NaN                                      NaN
# 64854                NaN                                      NaN
# 64855                NaN                                      NaN
# ...                  ...                                      ...
# 154556               NaN                                      NaN
# 154557               NaN                                      NaN
# 154558               NaN                                      NaN
# 154559               NaN                                      NaN
# 154560               NaN                                      NaN
#
# [1382 rows x 67 columns]

# %%
df_new.to_csv('filtered_data')
